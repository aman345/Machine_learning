# %%
import pandas as pd

# %%
dataset = pd.read_csv('data.csv')
X = dataset.iloc[:,1:-1] 
y = dataset.iloc[:,5]
dataset
# Out:
#     ID    Age  Income  Gender Marital Status Buys
# 0    1    <21    High    Male         Single   No
# 1    2    <21    High    Male        Married  Yes
# 2    3  21-35    High    Male         Single  Yes
# 3    4    >35  Medium    Male         Single  Yes
# 4    5    >35     Low  Female         Single   No
# 5    6    >35     Low  Female        Married  Yes
# 6    7  21-35     Low  Female        Married   No
# 7    8    <21  Medium    Male         Single  Yes
# 8    9    <21     Low  Female        Married  Yes
# 9   10    >35  Medium  Female         Single  Yes
# 10  11    <21  Medium  Female        Married  Yes
# 11  12  21-35  Medium    Male        Married  Yes
# 12  13  21-35    High  Female         Single  Yes
# 13  14    >35  Medium    Male        Marital   No

# %%
X
# Out:
#       Age  Income  Gender Marital Status
# 0     <21    High    Male         Single
# 1     <21    High    Male        Married
# 2   21-35    High    Male         Single
# 3     >35  Medium    Male         Single
# 4     >35     Low  Female         Single
# 5     >35     Low  Female        Married
# 6   21-35     Low  Female        Married
# 7     <21  Medium    Male         Single
# 8     <21     Low  Female        Married
# 9     >35  Medium  Female         Single
# 10    <21  Medium  Female        Married
# 11  21-35  Medium    Male        Married
# 12  21-35    High  Female         Single
# 13    >35  Medium    Male        Marital

# %%
y
# Out:
# 0      No
# 1     Yes
# 2     Yes
# 3     Yes
# 4      No
# 5     Yes
# 6      No
# 7     Yes
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13     No
# Name: Buys, dtype: object

# %%
#label encoder
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
X = X.apply(le.fit_transform)
X
# Out:
#     Age  Income  Gender  Marital Status
# 0     1       0       1               2
# 1     1       0       1               1
# 2     0       0       1               2
# 3     2       2       1               2
# 4     2       1       0               2
# 5     2       1       0               1
# 6     0       1       0               1
# 7     1       2       1               2
# 8     1       1       0               1
# 9     2       2       0               2
# 10    1       2       0               1
# 11    0       2       1               1
# 12    0       0       0               2
# 13    2       2       1               0

# %%
#model building and tranning phase
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#prediction phase 
import numpy  as np
X_in = np.array([1,1,0,0])
y_pred = model.predict([X_in])
print(y_pred)
# Out:
# ['No']

# %%
#displaying the graphical representation of tree
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(model,out_file=dot_data)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
p = Image(graph.create_png())
display(p)

# %%
from sklearn import tree
print(tree.export_graphviz(model, out_file='tree.dot'))
# Out:
# None
